# %% [markdown]
# <a href="https://colab.research.google.com/github/vfrantc/mmaction2/blob/main/cuny/experiments/no_pretrain_mvit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# INSTALL REQUIREMENTS AND MMACTION
# !pip install pytorchvideo --quiet
# !pip install timm --quiet
# !pip install -U openmim --quiet
# !mim install mmengine --quiet
# !mim install mmcv --quiet
# !mim install mmdet --quiet
# !mim install mmpose --quiet

# INSTALL MMACTION, OUR CONFIGS ARE THERE AS WELL
# %cd /content/
# !rm -r /content/mmaction2/
# !git clone https://github.com/vfrantc/mmaction2.git
# %cd mmaction2
# !pip install -v -e .

# COPY DATASET
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# !cp /content/drive/MyDrive/cuny_dataset/cuny_dataset.zip .
# !unzip -qq cuny_dataset.zip
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 36.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 5.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for pytorchvideo (setup.py) ... done
#   Building wheel for fvcore (setup.py) ... done
#   Building wheel for iopath (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 35.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 33.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.2/299.2 kB 26.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 26.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 24.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 47.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.8/143.8 kB 18.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 13.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.0/94.0 kB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 443.0/443.0 kB 46.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for oss2 (setup.py) ... done
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Building wheel for crcmod (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# lida 0.0.10 requires fastapi, which is not installed.
# lida 0.0.10 requires kaleido, which is not installed.
# lida 0.0.10 requires python-multipart, which is not installed.
# lida 0.0.10 requires uvicorn, which is not installed.
# cvxpy 1.3.3 requires setuptools>65.5.1, but you have setuptools 60.2.0 which is incompatible.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.28.2 which is incompatible.
# yfinance 0.2.36 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 451.7/451.7 kB 9.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.7/254.7 kB 28.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.1/94.1 MB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 31.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 27.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.6/50.6 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 436.0/436.0 kB 43.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 78.7 MB/s eta 0:00:00
#   Building wheel for chumpy (setup.py) ... done
# /content
# rm: cannot remove '/content/mmaction2/': No such file or directory
# Cloning into 'mmaction2'...
# remote: Enumerating objects: 22476, done.
# remote: Counting objects: 100% (390/390), done.
# remote: Compressing objects: 100% (195/195), done.
# remote: Total 22476 (delta 224), reused 340 (delta 189), pack-reused 22086
# Receiving objects: 100% (22476/22476), 65.55 MiB | 15.34 MiB/s, done.
# Resolving deltas: 100% (15768/15768), done.
# /content/mmaction2
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Obtaining file:///content/mmaction2
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-y5g63vn5/mmaction2.egg-info
#   writing manifest file '/tmp/pip-pip-egg-info-y5g63vn5/mmaction2.egg-info/SOURCES.txt'
#   warning: no files found matching 'mmaction/.mim/model-index.yml'
#   warning: no files found matching 'mmaction/.mim/dataset-index.yml'
#   warning: no files found matching '*.py' under directory 'mmaction/.mim/configs'
#   warning: no files found matching '*.yml' under directory 'mmaction/.mim/configs'
#   warning: no files found matching '*.sh' under directory 'mmaction/.mim/tools'
#   warning: no files found matching '*.py' under directory 'mmaction/.mim/tools'
#   writing manifest file '/tmp/pip-pip-egg-info-y5g63vn5/mmaction2.egg-info/SOURCES.txt'
#   Preparing metadata (setup.py) ... done
# Collecting decord>=0.4.1 (from mmaction2==1.2.0)
#   Downloading decord-0.6.0-py3-none-manylinux2010_x86_64.whl (13.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.6/13.6 MB 57.4 MB/s eta 0:00:00
# Collecting einops (from mmaction2==1.2.0)
#   Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mmaction2==1.2.0) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mmaction2==1.2.0) (1.23.5)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.10/dist-packages (from mmaction2==1.2.0) (4.8.0.76)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from mmaction2==1.2.0) (9.4.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from mmaction2==1.2.0) (1.11.4)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.10/dist-packages (from mmaction2==1.2.0) (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->mmaction2==1.2.0) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->mmaction2==1.2.0) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->mmaction2==1.2.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->mmaction2==1.2.0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->mmaction2==1.2.0) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->mmaction2==1.2.0) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->mmaction2==1.2.0) (2.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmaction2==1.2.0) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmaction2==1.2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmaction2==1.2.0) (4.48.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmaction2==1.2.0) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmaction2==1.2.0) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmaction2==1.2.0) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mmaction2==1.2.0) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mmaction2==1.2.0) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3->mmaction2==1.2.0) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3->mmaction2==1.2.0) (1.3.0)
# Installing collected packages: einops, decord, mmaction2
#   Running setup.py develop for mmaction2
#     Running command python setup.py develop
#     running develop
#     /usr/local/lib/python3.10/dist-packages/setuptools/command/easy_install.py:156: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     /usr/local/lib/python3.10/dist-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#       warnings.warn(
#     running egg_info
#     creating mmaction2.egg-info
#     writing manifest file 'mmaction2.egg-info/SOURCES.txt'
#     writing manifest file 'mmaction2.egg-info/SOURCES.txt'
#     running build_ext
# Successfully installed decord-0.6.0 einops-0.7.0 mmaction2-1.2.0
# Mounted at /content/drive

# %%
# !mv content/mmaction2/data .

# %% [markdown]
# # Train

# %%
# !python ./tools/train.py ./cuny/configs/mvit/no_pretrain_mvit-base-p244_32x3x1_kinetics400-rgb.py
# Out:
# 02/09 15:42:54 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
#     CUDA available: True
#     MUSA available: False
#     numpy_random_seed: 1006491414
#     GPU 0: NVIDIA A100-SXM4-40GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 12.2, V12.2.140
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu121
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 12.1
#   - NVCC architecture flags: -gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86;-gencode;arch=compute_90,code=sm_90
#   - CuDNN 8.9.2
#   - Magma 2.6.1
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.1, CUDNN_VERSION=8.9.2, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-unused-function -Wno-unused-result -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=old-style-cast -Wno-invalid-partial-specialization -Wno-unused-private-field -Wno-aligned-allocation-unavailable -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Werror=cast-function-type -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_DISABLE_GPU_ASSERTS=ON, TORCH_VERSION=2.1.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF,
#
#     TorchVision: 0.16.0+cu121
#     OpenCV: 4.8.0
#     MMEngine: 0.10.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: 1006491414
#     diff_rank_seed: False
#     deterministic: False
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 02/09 15:42:55 - mmengine - INFO - Config:
# ann_file_test = 'data/kinetics400/kinetics400_val_list_videos.txt'
# ann_file_train = 'data/kinetics400/kinetics400_train_list_videos.txt'
# ann_file_val = 'data/kinetics400/kinetics400_val_list_videos.txt'
# auto_scale_lr = dict(base_batch_size=256, enable=False)
# base_lr = 0.0016
# data_root = 'data/kinetics400/videos_train'
# data_root_val = 'data/kinetics400/videos_val'
# dataset_type = 'VideoDataset'
# default_hooks = dict(
#     checkpoint=dict(
#         interval=3, max_keep_ckpts=5, save_best='auto', type='CheckpointHook'),
#     logger=dict(ignore_last=False, interval=100, type='LoggerHook'),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     runtime_info=dict(type='RuntimeInfoHook'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     sync_buffers=dict(type='SyncBuffersHook'),
#     timer=dict(type='IterTimerHook'))
# default_scope = 'mmaction'
# env_cfg = dict(
#     cudnn_benchmark=False,
#     dist_cfg=dict(backend='nccl'),
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0))
# file_client_args = dict(io_backend='disk')
# launcher = 'none'
# load_from = None
# log_level = 'INFO'
# log_processor = dict(by_epoch=True, type='LogProcessor', window_size=20)
# model = dict(
#     backbone=dict(
#         arch='base', drop_path_rate=0.3, temporal_size=32, type='MViT'),
#     cls_head=dict(
#         average_clips='prob',
#         in_channels=768,
#         label_smooth_eps=0.1,
#         num_classes=2,
#         type='MViTHead'),
#     data_preprocessor=dict(
#         blending=dict(
#             augments=[
#                 dict(alpha=0.8, num_classes=400, type='MixupBlending'),
#                 dict(alpha=1, num_classes=400, type='CutmixBlending'),
#             ],
#             type='RandomBatchAugment'),
#         format_shape='NCTHW',
#         mean=[
#             114.75,
#             114.75,
#             114.75,
#         ],
#         std=[
#             57.375,
#             57.375,
#             57.375,
#         ],
#         type='ActionDataPreprocessor'),
#     type='Recognizer3D')
# optim_wrapper = dict(
#     clip_grad=dict(max_norm=1, norm_type=2),
#     optimizer=dict(
#         betas=(
#             0.9,
#             0.999,
#         ), lr=0.0016, type='AdamW', weight_decay=0.05),
#     paramwise_cfg=dict(bias_decay_mult=0.0, norm_decay_mult=0.0))
# param_scheduler = [
#     dict(
#         begin=0,
#         by_epoch=True,
#         convert_to_iter_based=True,
#         end=30,
#         start_factor=0.01,
#         type='LinearLR'),
#     dict(
#         T_max=200,
#         begin=30,
#         by_epoch=True,
#         convert_to_iter_based=True,
#         end=200,
#         eta_min=1.6e-05,
#         type='CosineAnnealingLR'),
# ]
# randomness = dict(deterministic=False, diff_rank_seed=False, seed=None)
# repeat_sample = 2
# resume = False
# test_cfg = dict(type='TestLoop')
# test_dataloader = dict(
#     batch_size=1,
#     dataset=dict(
#         ann_file='data/kinetics400/kinetics400_val_list_videos.txt',
#         data_prefix=dict(video='data/kinetics400/videos_val'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=3,
#                 num_clips=5,
#                 test_mode=True,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 224,
#             ), type='Resize'),
#             dict(crop_size=224, type='CenterCrop'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         test_mode=True,
#         type='VideoDataset'),
#     num_workers=8,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# test_evaluator = dict(type='AccMetric')
# test_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(
#         clip_len=32,
#         frame_interval=3,
#         num_clips=5,
#         test_mode=True,
#         type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         224,
#     ), type='Resize'),
#     dict(crop_size=224, type='CenterCrop'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# train_cfg = dict(
#     max_epochs=200, type='EpochBasedTrainLoop', val_begin=1, val_interval=1)
# train_dataloader = dict(
#     batch_size=2,
#     collate_fn=dict(type='repeat_pseudo_collate'),
#     dataset=dict(
#         ann_file='data/kinetics400/kinetics400_train_list_videos.txt',
#         data_prefix=dict(video='data/kinetics400/videos_train'),
#         num_repeats=2,
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=3,
#                 num_clips=1,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 256,
#             ), type='Resize'),
#             dict(
#                 magnitude=7,
#                 num_layers=4,
#                 op='RandAugment',
#                 type='PytorchVideoWrapper'),
#             dict(type='RandomResizedCrop'),
#             dict(keep_ratio=False, scale=(
#                 224,
#                 224,
#             ), type='Resize'),
#             dict(flip_ratio=0.5, type='Flip'),
#             dict(erase_prob=0.25, mode='rand', type='RandomErasing'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         sample_once=True,
#         type='RepeatAugDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=True, type='DefaultSampler'))
# train_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(clip_len=32, frame_interval=3, num_clips=1, type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         256,
#     ), type='Resize'),
#     dict(
#         magnitude=7,
#         num_layers=4,
#         op='RandAugment',
#         type='PytorchVideoWrapper'),
#     dict(type='RandomResizedCrop'),
#     dict(keep_ratio=False, scale=(
#         224,
#         224,
#     ), type='Resize'),
#     dict(flip_ratio=0.5, type='Flip'),
#     dict(erase_prob=0.25, mode='rand', type='RandomErasing'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# val_cfg = dict(type='ValLoop')
# val_dataloader = dict(
#     batch_size=2,
#     dataset=dict(
#         ann_file='data/kinetics400/kinetics400_val_list_videos.txt',
#         data_prefix=dict(video='data/kinetics400/videos_val'),
#         pipeline=[
#             dict(io_backend='disk', type='DecordInit'),
#             dict(
#                 clip_len=32,
#                 frame_interval=3,
#                 num_clips=1,
#                 test_mode=True,
#                 type='SampleFrames'),
#             dict(type='DecordDecode'),
#             dict(scale=(
#                 -1,
#                 256,
#             ), type='Resize'),
#             dict(crop_size=224, type='CenterCrop'),
#             dict(input_format='NCTHW', type='FormatShape'),
#             dict(type='PackActionInputs'),
#         ],
#         test_mode=True,
#         type='VideoDataset'),
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(shuffle=False, type='DefaultSampler'))
# val_evaluator = dict(type='AccMetric')
# val_pipeline = [
#     dict(io_backend='disk', type='DecordInit'),
#     dict(
#         clip_len=32,
#         frame_interval=3,
#         num_clips=1,
#         test_mode=True,
#         type='SampleFrames'),
#     dict(type='DecordDecode'),
#     dict(scale=(
#         -1,
#         256,
#     ), type='Resize'),
#     dict(crop_size=224, type='CenterCrop'),
#     dict(input_format='NCTHW', type='FormatShape'),
#     dict(type='PackActionInputs'),
# ]
# vis_backends = [
#     dict(type='LocalVisBackend'),
# ]
# visualizer = dict(
#     type='ActionVisualizer', vis_backends=[
#         dict(type='LocalVisBackend'),
#     ])
# work_dir = './work_dirs/no_pretrain_mvit-base-p244_32x3x1_kinetics400-rgb'
#
# 02/09 15:43:00 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 02/09 15:43:00 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) SyncBuffersHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# /usr/local/lib/python3.10/dist-packages/torchvision/transforms/functional_tensor.py:5: UserWarning: The torchvision.transforms.functional_tensor module is deprecated in 0.15 and will be **removed in 0.17**. Please don't rely on it. You probably just need to use APIs in torchvision.transforms.functional or in torchvision.transforms.v2.functional.
#   warnings.warn(
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.patch_embed.projection.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.0.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.1.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.2.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.3.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.4.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.5.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.6.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.7.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.8.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.9.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.10.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.11.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.12.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.13.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.14.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.15.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.16.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.17.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.18.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.19.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.20.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.21.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.22.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.norm1.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.norm1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.attn.qkv.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.attn.proj.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.attn.norm_q.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.attn.norm_q.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.attn.norm_k.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.attn.norm_k.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.attn.norm_v.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.attn.norm_v.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.norm2.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.norm2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.mlp.fc1.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.blocks.23.mlp.fc2.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.norm3.weight:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- backbone.norm3.bias:weight_decay=0.0
# 02/09 15:43:01 - mmengine - INFO - paramwise_options -- cls_head.fc_cls.bias:weight_decay=0.0
# 02/09 15:43:03 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 02/09 15:43:03 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 02/09 15:43:03 - mmengine - INFO - Checkpoints will be saved to /content/mmaction2/work_dirs/no_pretrain_mvit-base-p244_32x3x1_kinetics400-rgb.
# Traceback (most recent call last):
#   File "/content/mmaction2/./tools/train.py", line 143, in <module>
#     main()
#   File "/content/mmaction2/./tools/train.py", line 139, in main
#     runner.train()
#   File "/usr/local/lib/python3.10/dist-packages/mmengine/runner/runner.py", line 1777, in train
#     model = self.train_loop.run()  # type: ignore
#   File "/usr/local/lib/python3.10/dist-packages/mmengine/runner/loops.py", line 96, in run
#     self.run_epoch()
#   File "/usr/local/lib/python3.10/dist-packages/mmengine/runner/loops.py", line 112, in run_epoch
#     self.run_iter(idx, data_batch)
#   File "/usr/local/lib/python3.10/dist-packages/mmengine/runner/loops.py", line 128, in run_iter
#     outputs = self.runner.model.train_step(
#   File "/usr/local/lib/python3.10/dist-packages/mmengine/model/base_model/base_model.py", line 114, in train_step
#     losses = self._run_forward(data, mode='loss')  # type: ignore
#   File "/usr/local/lib/python3.10/dist-packages/mmengine/model/base_model/base_model.py", line 361, in _run_forward
#     results = self(**data, mode=mode)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1518, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1527, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/content/mmaction2/mmaction/models/recognizers/base.py", line 262, in forward
#     return self.loss(inputs, data_samples, **kwargs)
#   File "/content/mmaction2/mmaction/models/recognizers/base.py", line 176, in loss
#     loss_cls = self.cls_head.loss(feats, data_samples, **loss_kwargs)
#   File "/content/mmaction2/mmaction/models/heads/base.py", line 99, in loss
#     return self.loss_by_feat(cls_scores, data_samples)
#   File "/content/mmaction2/mmaction/models/heads/base.py", line 129, in loss_by_feat
#     top_k_acc = top_k_accuracy(cls_scores.detach().cpu().numpy(),
#   File "/content/mmaction2/mmaction/evaluation/functional/accuracy.py", line 149, in top_k_accuracy
#     match_array = np.logical_or.reduce(max_k_preds == labels, axis=1)
# numpy.AxisError: axis 1 is out of bounds for array of dimension 0

# %%
# !cp -r work_dirs /content/drive/MyDrive/cuny_dataset/
