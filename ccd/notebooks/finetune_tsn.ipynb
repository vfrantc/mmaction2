# %% [markdown]
# <a href="https://colab.research.google.com/github/vfrantc/mmaction2/blob/main/ccd/notebooks/finetune_tsn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/vfrantc/mmaction2.git
# %cd mmaction2
# !pip install -v -e .
# !pip install -U openmim
# !mim install mmengine
# !mim install mmcv
# !mim install mmdet
# !mim install mmpose
# Out:
# Cloning into 'mmaction2'...
# remote: Enumerating objects: 22242, done.
# remote: Counting objects: 100% (156/156), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 22242 (delta 87), reused 138 (delta 75), pack-reused 22086
# Receiving objects: 100% (22242/22242), 65.17 MiB | 3.68 MiB/s, done.
# Resolving deltas: 100% (15645/15645), done.
# /content/mmaction2
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Obtaining file:///content/mmaction2
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-psedz56c/mmaction2.egg-info
#   writing /tmp/pip-pip-egg-info-psedz56c/mmaction2.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-psedz56c/mmaction2.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-psedz56c/mmaction2.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-psedz56c/mmaction2.egg-info/top_level.txt
# ...

# %%
# !cp -r /content/drive/MyDrive/accident-detection/mini_ds.zip .
# !unzip -q mini_ds.zip

# %%
# !mv mini_ds data

# %%
# !python ./tools/data/activitynet/generate_rawframes_filelist.py
# Out:
# Counting files from: ./data/ActivityNet/rawframes/0DWnRW3NSYQ
# Counting files from: ./data/ActivityNet/rawframes/_VA1hvHU2FA
# Counting files from: ./data/ActivityNet/rawframes/_dWSizFvW5Y
# Counting files from: ./data/ActivityNet/rawframes/_ipUUrhA5BY
# Counting files from: ./data/ActivityNet/rawframes/_xCP0_3F5-c
# Counting files from: ./data/ActivityNet/rawframes/0BGcHXHaPKg
# Counting files from: ./data/ActivityNet/rawframes/_eQPaGDhUUg
# Counting files from: ./data/ActivityNet/rawframes/_hx3Sm-jGyU
# Counting files from: ./data/ActivityNet/rawframes/_I23eDPf0fQ

# %%
# !ls data/ActivityNet/
# Out:
# activitynet_ready_minilabels.json  anet_train_video.txt  rawframes
# activity_net.v1-3.min.json	   anet_val_clip.txt	 video_info_new.csv
# anet_train_clip.txt		   anet_val_video.txt	 videos

# %% [markdown]
# # Finetune

# %%
# !pip install timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 14.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### RGB

# %%
# !python tools/train.py ccd/configs/tsn_r50_320p_1x1x8_10e_rgb_activitynet_finetune.py
# Out:
# 11/30 20:20:53 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
#     CUDA available: True
#     numpy_random_seed: 594453630
#     GPU 0: Tesla V100-SXM2-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
# ...

# %% [markdown]
# ### Optical flow

# %%
# !python tools/train.py ccd/configs/tsn_r50_320p_1x1x8_10e_flow_activitynet_finetune.py
# Out:
# 11/30 20:15:57 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
#     CUDA available: True
#     numpy_random_seed: 1201353893
#     GPU 0: Tesla V100-SXM2-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
# ...

# %% [markdown]
# # Models

# %%
# !ls ./rgb_checkpoints/
# Out:
# 20231130_202052		   epoch_25.pth  epoch_41.pth
# best_acc_top1_epoch_1.pth  epoch_26.pth  epoch_42.pth
# epoch_10.pth		   epoch_27.pth  epoch_43.pth
# epoch_11.pth		   epoch_28.pth  epoch_44.pth
# epoch_12.pth		   epoch_29.pth  epoch_45.pth
# epoch_13.pth		   epoch_2.pth	 epoch_46.pth
# epoch_14.pth		   epoch_30.pth  epoch_47.pth
# epoch_15.pth		   epoch_31.pth  epoch_48.pth
# epoch_16.pth		   epoch_32.pth  epoch_49.pth
# epoch_17.pth		   epoch_33.pth  epoch_4.pth
# epoch_18.pth		   epoch_34.pth  epoch_50.pth
# epoch_19.pth		   epoch_35.pth  epoch_5.pth
# epoch_1.pth		   epoch_36.pth  epoch_6.pth
# epoch_20.pth		   epoch_37.pth  epoch_7.pth
# epoch_21.pth		   epoch_38.pth  epoch_8.pth
# epoch_22.pth		   epoch_39.pth  epoch_9.pth
# epoch_23.pth		   epoch_3.pth	 last_checkpoint
# epoch_24.pth		   epoch_40.pth  tsn_r50_320p_1x1x8_10e_rgb_activitynet_finetune.py

# %%
# !ls ./flow_checkpoints/
# Out:
# 20231130_194611		   epoch_25.pth  epoch_42.pth
# 20231130_201556		   epoch_26.pth  epoch_43.pth
# best_acc_top1_epoch_1.pth  epoch_27.pth  epoch_44.pth
# epoch_10.pth		   epoch_28.pth  epoch_45.pth
# epoch_11.pth		   epoch_29.pth  epoch_46.pth
# epoch_12.pth		   epoch_2.pth	 epoch_47.pth
# epoch_13.pth		   epoch_30.pth  epoch_48.pth
# epoch_14.pth		   epoch_31.pth  epoch_49.pth
# epoch_15.pth		   epoch_32.pth  epoch_4.pth
# epoch_16.pth		   epoch_33.pth  epoch_50.pth
# epoch_17.pth		   epoch_34.pth  epoch_5.pth
# epoch_18.pth		   epoch_35.pth  epoch_6.pth
# epoch_19.pth		   epoch_36.pth  epoch_7.pth
# epoch_1.pth		   epoch_37.pth  epoch_8.pth
# epoch_20.pth		   epoch_38.pth  epoch_9.pth
# epoch_21.pth		   epoch_39.pth  last_checkpoint
# epoch_22.pth		   epoch_3.pth	 tsn_r50_320p_1x1x8_10e_flow_activitynet_finetune.py
# epoch_23.pth		   epoch_40.pth
# epoch_24.pth		   epoch_41.pth

# %%
# !cp ./rgb_checkpoints/epoch_50.pth /content/drive/MyDrive/accident-detection/models/tsn_r50_320p_1x1x8_10e_rgb_activitynet_finetune.pth
# !cp ./flow_checkpoints/epoch_50.pth /content/drive/MyDrive/accident-detection/models/tsn_r50_320p_1x1x8_10e_flow_activitynet_finetune.pth

# %%
# !cp ./rgb_checkpoints/best_acc_top1_epoch_1.pth /content/drive/MyDrive/accident-detection/models/tsn_r50_320p_1x1x8_10e_rgb_activitynet_finetune_small.pth
# !cp ./flow_checkpoints/best_acc_top1_epoch_1.pth /content/drive/MyDrive/accident-detection/models/tsn_r50_320p_1x1x8_10e_flow_activitynet_finetune_small.pth
