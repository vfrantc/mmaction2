# %% [markdown]
# <a href="https://colab.research.google.com/github/vfrantc/mmaction2/blob/main/ccd/notebooks/extract_features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 14.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/vfrantc/mmaction2.git
# %cd mmaction2
# !pip install -v -e .
# !pip install -U openmim
# !mim install mmengine
# !mim install mmcv
# !mim install mmdet
# !mim install mmpose
# Out:
# Cloning into 'mmaction2'...
# remote: Enumerating objects: 22242, done.
# remote: Counting objects: 100% (156/156), done.
# remote: Compressing objects: 100% (77/77), done.
# remote: Total 22242 (delta 87), reused 138 (delta 75), pack-reused 22086
# Receiving objects: 100% (22242/22242), 65.17 MiB | 9.98 MiB/s, done.
# Resolving deltas: 100% (15650/15650), done.
# /content/mmaction2
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Obtaining file:///content/mmaction2
#   Running command python setup.py egg_info
#   running egg_info
#   creating /tmp/pip-pip-egg-info-v_69wppv/mmaction2.egg-info
#   writing /tmp/pip-pip-egg-info-v_69wppv/mmaction2.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-pip-egg-info-v_69wppv/mmaction2.egg-info/dependency_links.txt
#   writing requirements to /tmp/pip-pip-egg-info-v_69wppv/mmaction2.egg-info/requires.txt
#   writing top-level names to /tmp/pip-pip-egg-info-v_69wppv/mmaction2.egg-info/top_level.txt
# ...

# %%
# !cp -r /content/drive/MyDrive/accident-detection/mini_ds.zip .
# !unzip -q mini_ds.zip

# %%
# !mv mini_ds data

# %%
# !python ./tools/data/activitynet/generate_rawframes_filelist.py
# Out:
# Counting files from: ./data/ActivityNet/rawframes/0DWnRW3NSYQ
# Counting files from: ./data/ActivityNet/rawframes/_VA1hvHU2FA
# Counting files from: ./data/ActivityNet/rawframes/_dWSizFvW5Y
# Counting files from: ./data/ActivityNet/rawframes/_ipUUrhA5BY
# Counting files from: ./data/ActivityNet/rawframes/_xCP0_3F5-c
# Counting files from: ./data/ActivityNet/rawframes/0BGcHXHaPKg
# Counting files from: ./data/ActivityNet/rawframes/_eQPaGDhUUg
# Counting files from: ./data/ActivityNet/rawframes/_hx3Sm-jGyU
# Counting files from: ./data/ActivityNet/rawframes/_I23eDPf0fQ

# %% [markdown]
# # Finetune

# %%
# !pip install timm

# %% [markdown]
# # Feature extraction

# %%
# !cp -r /content/drive/MyDrive/accident-detection/models .

# %%
# !ls ccd/configs
# Out:
# tsn_r50_320p_1x1x8_10e_flow_activitynet_finetune.py
# tsn_r50_320p_1x1x8_10e_rgb_activitynet_finetune.py

# %%
# !ls ccd/configs/tsn_r50_320p_1x1x8_10e_flow_activitynet_finetune.py
# Out:
# tsn_r50_320p_1x1x8_10e_flow_activitynet_finetune.py
# tsn_r50_320p_1x1x8_10e_rgb_activitynet_finetune.py

# %%
# !ls models
# Out:
# tsn_r50_320p_1x1x8_10e_flow_activitynet_finetune.pth
# tsn_r50_320p_1x1x8_10e_flow_activitynet_finetune_small.pth
# tsn_r50_320p_1x1x8_10e_rgb_activitynet_finetune.pth
# tsn_r50_320p_1x1x8_10e_rgb_activitynet_finetune_small.pth

# %%
# !mkdir features

# %%
# !ls ./data/ActivityNet/
# Out:
# activitynet_ready_minilabels.json  anet_train_video.txt  rawframes
# activity_net.v1-3.min.json	   anet_val_clip.txt	 video_info_new.csv
# anet_train_clip.txt		   anet_val_video.txt	 videos

# %%
# !python ./tools/misc/clip_feature_extraction.py ccd/configs/tsn_r50_320p_1x1x8_10e_flow_activitynet_finetune.py ./models/tsn_r50_320p_1x1x8_10e_flow_activitynet_finetune.pth ./features/flow_train_feat.pkl --video-list /content/mmaction2/data/ActivityNet/anet_train_video.txt --video-root /content/mmaction2/data/ActivityNet/rawframes
# Out:
# 11/30 22:20:58 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
#     CUDA available: True
#     numpy_random_seed: 2029862145
#     GPU 0: Tesla V100-SXM2-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
# ...

# %%
# !ls /content/mmaction2/data/ActivityNet/rawframes/0BGcHXHaPKg/flow_x_01994.jpg
# Out:
# ls: cannot access '/content/mmaction2/data/ActivityNet/rawframes/0BGcHXHaPKg/flow_x_01994.jpg': No such file or directory

# %%
# !ls ./data/ActivityNet/
# Out:
# activitynet_ready_minilabels.json  anet_train_video.txt  rawframes
# activity_net.v1-3.min.json	   anet_val_clip.txt	 video_info_new.csv
# anet_train_clip.txt		   anet_val_video.txt	 videos

# %%
# !python ./tools/misc/clip_feature_extraction.py ccd/configs/tsn_r50_320p_1x1x8_10e_flow_activitynet_finetune.py ./models/tsn_r50_320p_1x1x8_10e_flow_activitynet_finetune.pth ./features/flow_val_feat.pkl --video-list /content/mmaction2/data/ActivityNet/anet_val_video.txt --video-root /content/mmaction2/data/ActivityNet/rawframes
# Out:
# 11/30 21:40:12 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
#     CUDA available: True
#     numpy_random_seed: 1986023282
#     GPU 0: Tesla V100-SXM2-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
# ...

# %%
# !python ./tools/misc/clip_feature_extraction.py ccd/configs/tsn_r50_320p_1x1x8_10e_rgb_activitynet_finetune.py ./models/tsn_r50_320p_1x1x8_10e_rgb_activitynet_finetune.pth ./features/rgb_train_feat.pkl --video-list /content/mmaction2/data/ActivityNet/anet_train_video.txt --video-root /content/mmaction2/data/ActivityNet/rawframes
# Out:
# 11/30 21:40:30 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
#     CUDA available: True
#     numpy_random_seed: 1914210258
#     GPU 0: Tesla V100-SXM2-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
# ...

# %%
# !python ./tools/misc/clip_feature_extraction.py ccd/configs/tsn_r50_320p_1x1x8_10e_rgb_activitynet_finetune.py ./models/tsn_r50_320p_1x1x8_10e_rgb_activitynet_finetune.pth ./features/rgb_val_feat.pkl --video-list /content/mmaction2/data/ActivityNet/anet_val_video.txt --video-root /content/mmaction2/data/ActivityNet/rawframes
# Out:
# 11/30 21:46:29 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
#     CUDA available: True
#     numpy_random_seed: 629504141
#     GPU 0: Tesla V100-SXM2-16GB
#     CUDA_HOME: /usr/local/cuda
#     NVCC: Cuda compilation tools, release 11.8, V11.8.89
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.1.0+cu118
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2022.2-Product Build 20220804 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.1.1 (Git Hash 64f6bcbcbab628e96f33a62c3e975f8535a7bde4)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX512
#   - CUDA Runtime 11.8
# ...

# %%
# !ls features
# Out:
# flow_train_feat.pkl  flow_val_feat.pkl	rgb_train_feat.pkl  rgb_val_feat.pkl

# %%
import pickle
import pprint

# Load the data from the pickle file
with open('/content/mmaction2/data/ActivityNet/rgb_tarin_feat.pkl/0BGcHXHaPKg.pkl', 'rb') as file:
    data = pickle.load(file)
for row in data:
    pprint.pprint(row)
